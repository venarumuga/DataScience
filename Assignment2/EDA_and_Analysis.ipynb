# %% [markdown]
# # EDA & DATA PREPROCESSING

# %% [markdown]
# #Points
# 1. Read the data and Load
# 2. Merge dataset or add column names if requried
# 3. Understand dataset features and values
# 4. Variable Identification
# 5. Univariate Analysis
# 6. Bi-variate Analysis
# 7. Missing Value Treatment
# 8. Outlier Detection and Treatment
# 9. Feature Engineering
#     -->Feature transformation.
#     -->Feature creation
# 10.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt # this is for visualization
import seaborn as sns # for visualization

# %%
data= pd.read_csv("bigcity.csv",na_values = ['no info', '.'])

# %%
data.head()
# Out:
#    id     C1     C2
# 0   1  138.0  143.0
# 1   2    NaN  104.0
# 2   3   61.0   69.0
# 3   4  179.0  260.0
# 4   5   48.0    NaN

# %%
df= pd.read_csv("bigcity.csv",header=None,index_col=0)

# %%
df.head()
# Out:
#       1    2
# 0
# id   C1   C2
# 1   138  143
# 2   NaN  104
# 3    61   69
# 4   179  260

# %%
data1=pd.read_csv("/Users/z082092/Learning/Training/GL-Mentoring/SP-WK2/bigcity.csv")

# %%
data.head(5)
# Out:
#    1    138    143
# 0  2    NaN  104.0
# 1  3   61.0   69.0
# 2  4  179.0  260.0
# 3  5   48.0    NaN
# 4  6   37.0   63.0

# %%
data1.tail(5)
# Out:
#     id     C1     C2
# 44  45   87.0  105.0
# 45  46   43.0   61.0
# 46  47   43.0   50.0
# 47  48  161.0  232.0
# 48  49   36.0   54.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 3 columns):
# 1      48 non-null int64
# 138    47 non-null float64
# 143    47 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 1.2 KB

# %%
data1['C1'].dtypes
# Out:
# dtype('float64')

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
l=[1,2,3]

# %%
type(l)
# Out:
# list

# %%
d={1,2,3}

# %%
type(d)
# Out:
# set

# %%
A=np.record

# %%
A
# Out:
# numpy.record

# %%
data1= pd.read_json('json1.txt')

# %%
data1
# Out:
#             Product  Price
# 0  Desktop Computer    700
# 1            Tablet    250
# 2            iPhone    800
# 3            Laptop   1200

# %%
import json  
import pandas as pd  
from pandas.io.json import json_normalize

# %%
with open('/Users/z082092/Learning/Training/GL-Mentoring/SP-WK2/json.txt') as f: 
    d = json.load(f)

# %%
d
# Out:
# {'current': {'comment_history': [],
#   'ebatch': False,
#   'last_modified_date': 1573713028676,
#   'modified_by': 'system',
#   'sizes': [{'expected_sign_count': 1790,
#     'hide_reg_and_savings': False,
#     'previews': [{'context': {'hide_reg_and_savings': False,
#        'is_crv': False,
#        'is_unit_item': False,
#        'is_unit_store': False,
#        'offer_class': 'SALE',
#        'offer_end_date': 1576396799000,
#        'offer_id': '592024154',
#        'offer_start_date': 1575792000000,
#        'offer_type': 'SALE',
#        'params': {'BARCODE': {'type_value': 'BARCODE',
#          'value': '027242908192'},
#         'BUY_COUNT': {'type_value': 'TEXT', 'value': '0'},
#         'BUY_COUNT_TYPE': {'type_value': 'TEXT', 'value': 'NONE'},
#         'DISCLAIMERS': {'type_value': 'TEXT', 'value': ''},
#         'DPCI': {'type_value': 'TEXT', 'value': '008-02-0021'},
#         'EXCLUSIONS': {'type_value': 'TEXT', 'value': ''},
# ...

# %%
data1 = [['samik', 10], ['venkat', 15], ['Ashish', 14]]

# %%
data2 = [['ramya', 15], ['ritu', 18], ['Asha', 20]]

# %%
df1 = pd.DataFrame(data1, columns = ['Name', 'Age'])

# %%
df2 = pd.DataFrame(data2, columns = ['Name', 'Age'])

# %%
df = pd.concat([df1,df2])

# %%
df
# Out:
#      Name  Age
# 0   samik   10
# 1  venkat   15
# 2  Ashish   14
# 0   ramya   15
# 1    ritu   18
# 2    Asha   20

# %%
print("data Information :",df.info)
# Out:
# data Information : <bound method DataFrame.info of      Name  Age
# 0   samik   10
# 1  venkat   15
# 2  Ashish   14
# 0   ramya   15
# 1    ritu   18
# 2    Asha   20>

# %%
data = [{'b': 2, 'c':3}, {'a': 10, 'b': 20, 'c': 30}] 
df = pd.DataFrame(data, index =['first', 'second']) 
df
# Out:
#            a   b   c
# first    NaN   2   3
# second  10.0  20  30

# %%
#variable identification
# reading the CSV file into pandas dataframe
car_df = pd.read_csv("car-mpg-2.csv")

# %%
car_df.head()
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 0  18.0    8  307.0  130  3504  12.0  70       1         0
# 1  15.0    8  350.0  165  3693  11.5  70       1         0
# 2  18.0    8  318.0  150  3436  11.0  70       1         0
# 3  16.0    8  304.0  150  3433  12.0  70       1         0
# 4  17.0    8  302.0  140  3449  10.5  70       1         0
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
# mpg         398 non-null float64
# cyl         398 non-null int64
# disp        398 non-null float64
# hp          398 non-null object
# wt          398 non-null int64
# acc         398 non-null float64
# yr          398 non-null int64
# origin      398 non-null int64
# car_type    398 non-null int64
# car_name    398 non-null object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 31.2+ KB

# %%
car_df['mpg'].dtypes
# Out:
# dtype('float64')

# %%
g=car_df.groupby('mpg')

# %%
car_df.sort_values(car_df['mpg'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-128-fff091c8ca68> in <module>()
# ----> 1 car_df.sort_values(car_df['mpg'])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1705             values = self.axes[axis].get_level_values(key)._values
#    1706         else:
# -> 1707             raise KeyError(key)
#    1708
#    1709         # Check for duplicates
#
# KeyError: 397    31.0
# 380    36.0
# 387    38.0
# 384    32.0
# 385    38.0
# 386    25.0
# 388    26.0
# ...

# %%
g.first()
# Out:
#       cyl   disp   hp    wt   acc  yr  origin  car_type  \
# mpg
# 9.0     8  304.0  193  4732  18.5  70       1         0
# 10.0    8  360.0  215  4615  14.0  70       1         0
# 11.0    8  318.0  210  4382  13.5  70       1         0
# 12.0    8  383.0  180  4955  11.5  71       1         0
# 13.0    8  400.0  170  4746  12.0  71       1         0
# 14.0    8  454.0  220  4354   9.0  70       1         0
# 14.5    8  351.0  152  4215  12.8  76       1         0
# 15.0    8  350.0  165  3693  11.5  70       1         0
# 15.5    8  304.0  120  3962  13.9  76       1         0
# 16.0    8  304.0  150  3433  12.0  70       1         0
# 16.2    6  163.0  133  3410  15.8  78       2         0
# 16.5    6  168.0  120  3820  16.7  76       2         0
# 16.9    8  350.0  155  4360  14.9  79       1         0
# 17.0    8  302.0  140  3449  10.5  70       1         0
# 17.5    8  305.0  140  4215  13.0  76       1         0
# 17.6    8  302.0  129  3725  13.4  79       1         0
# ...

# %%
car_df.sort_values(["car_type"], axis=0, 
                 ascending=False, inplace=True)

# %%
car_df.head(5)
# Out:
#       mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 397  31.0    4  119.0   82  2720  19.4  82       1         1
# 46   22.0    4  140.0   72  2408  19.0  71       1         1
# 238  33.5    4   98.0   83  2075  15.9  77       1         1
# 243  21.5    3   80.0  110  2720  13.5  77       3         1
# 233  29.0    4   97.0   78  1940  14.5  77       2         1
#
#                      car_name
# 397                chevy s-10
# 46        chevrolet vega (sw)
# 238            dodge colt m/m
# 243                mazda rx-4
# 233  volkswagen rabbit custom

# %%
ary=np.random.random((2,2))

# %%
type(ary)
# Out:
# numpy.ndarray

# %%
type(car_df)
# Out:
# pandas.core.frame.DataFrame

# %%
car_df.head()
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin  car_type  \
# 0  18.0    8  307.0  130  3504  12.0  70       1         0
# 1  15.0    8  350.0  165  3693  11.5  70       1         0
# 2  18.0    8  318.0  150  3436  11.0  70       1         0
# 3  16.0    8  304.0  150  3433  12.0  70       1         0
# 4  17.0    8  302.0  140  3449  10.5  70       1         0
#
#                     car_name
# 0  chevrolet chevelle malibu
# 1          buick skylark 320
# 2         plymouth satellite
# 3              amc rebel sst
# 4                ford torino

# %%
#The CAR_NaME is not usedful column , it will not help for any model 
car_df.drop(['car_name'], axis=1, inplace=True)

# %%
car_df.head()
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin  car_type
# 0  18.0    8  307.0  130  3504  12.0  70       1         0
# 1  15.0    8  350.0  165  3693  11.5  70       1         0
# 2  18.0    8  318.0  150  3436  11.0  70       1         0
# 3  16.0    8  304.0  150  3433  12.0  70       1         0
# 4  17.0    8  302.0  140  3449  10.5  70       1         0

# %%
car_df['yr'].dtypes
# Out:
# dtype('int64')

# %%
#Univariant analysis

# %%
car_df.hist(bins=15, color='blue', edgecolor='black', linewidth=1.0,
              xlabelsize=8, ylabelsize=8, grid=False)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11755a080>,
# ...
#       dtype=object)

# %%
#to plot histograms
sns.distplot(car_df['mpg'],kde=False,bins=30)

# %%
sns.boxplot(car_df['mpg'])

# %%
#multi variate analysis / Bi -vairate analysis

# %%
car_df.describe().transpose()
# Out:
#           count         mean         std     min       25%     50%       75%  \
# mpg       398.0    23.514573    7.815984     9.0    17.500    23.0    29.000
# cyl       398.0     5.454774    1.701004     3.0     4.000     4.0     8.000
# disp      398.0   193.425879  104.269838    68.0   104.250   148.5   262.000
# wt        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5  3608.000
# acc       398.0    15.568090    2.757689     8.0    13.825    15.5    17.175
# yr        398.0    76.010050    3.697627    70.0    73.000    76.0    79.000
# origin    398.0     1.572864    0.802055     1.0     1.000     1.0     2.000
# car_type  398.0     0.530151    0.499718     0.0     0.000     1.0     1.000
#
#              max
# mpg         46.6
# cyl          8.0
# disp       455.0
# wt        5140.0
# acc         24.8
# yr          82.0
# origin       3.0
# car_type     1.0

# %%
car_df.corr()
# Out:
#                mpg       cyl      disp        wt       acc        yr  \
# mpg       1.000000 -0.775396 -0.804203 -0.831741  0.420289  0.579267
# cyl      -0.775396  1.000000  0.950721  0.896017 -0.505419 -0.348746
# disp     -0.804203  0.950721  1.000000  0.932824 -0.543684 -0.370164
# wt       -0.831741  0.896017  0.932824  1.000000 -0.417457 -0.306564
# acc       0.420289 -0.505419 -0.543684 -0.417457  1.000000  0.288137
# yr        0.579267 -0.348746 -0.370164 -0.306564  0.288137  1.000000
# origin    0.563450 -0.562543 -0.609409 -0.581024  0.205873  0.180662
# car_type  0.759207 -0.912577 -0.855141 -0.815445  0.385187  0.305194
#
#             origin  car_type
# mpg       0.563450  0.759207
# cyl      -0.562543 -0.912577
# disp     -0.609409 -0.855141
# wt       -0.581024 -0.815445
# acc       0.205873  0.385187
# yr        0.180662  0.305194
# origin    1.000000  0.572691
# car_type  0.572691  1.000000

# %%
sns.heatmap(car_df.corr(),annot=True)

# %%
f, ax = plt.subplots(figsize=(14,10))
corr = car_df.corr()
hm = sns.heatmap(round(corr,2), annot=True, ax=ax, cmap="coolwarm",fmt='.2f',
            linewidths=.05)
f.subplots_adjust(top=0.93)
t= f.suptitle('Attributes Correlation Heatmap', fontsize=14)

# %%
car_df.plot.scatter(y='mpg',x='cyl',alpha=0.5,figsize=(8,4),s=80)

# %%
sns.boxplot(x=car_df['origin'], y=car_df['mpg'])

# %%
temp = pd.DataFrame(car_df.hp.str.isdigit())

# %%
temp[temp['hp'] == False]   # from temp take only those rows where hp has false
# Out:
#         hp
# 32   False
# 126  False
# 330  False
# 336  False
# 354  False
# 374  False

# %% [markdown]
# ### Missing Value Treatment
#   1. Delete
#   2. Mean/ Mode/ Median or any value  Imputationion
#   3. Nearest value / use KNN
#   4. Create model and predict mean ( )

# %% [markdown]
# isnull()
# notnull()
# dropna()
# fillna()
# replace()
# interpolate()

# %%
# importing pandas as pd 
import pandas as pd 
  
# importing numpy as np 
import numpy as np 
  
# dictionary of lists 
dict = {'First Score':[100, 90, np.nan, 95], 
        'Second Score': [30, 45, 56, np.nan], 
        'Third Score':[np.nan, 40, 80, 98]} 
  
# creating a dataframe using dictionary 
df = pd.DataFrame(dict) 
  
# using notnull() function  
df.notnull()
# Out:
#    First Score  Second Score  Third Score
# 0         True          True        False
# 1         True          True         True
# 2        False          True         True
# 3         True         False         True

# %%
df.fillna(0)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0          0.0
# 1         90.0          45.0         40.0
# 2          0.0          56.0         80.0
# 3         95.0           0.0         98.0

# %%
df.dropna(0)
# Out:
#    First Score  Second Score  Third Score
# 1         90.0          45.0         40.0

# %%
df.fillna(method ='bfill')
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0         40.0
# 1         90.0          45.0         40.0
# 2         95.0          56.0         80.0
# 3         95.0           NaN         98.0

# %%
df.replace(to_replace = np.nan, value = -99)
# Out:
#    First Score  Second Score  Third Score
# 0        100.0          30.0        -99.0
# 1         90.0          45.0         40.0
# 2        -99.0          56.0         80.0
# 3         95.0         -99.0         98.0

# %%
df.fillna(df.mode())
# Out:
#      country
# 0     russia
# 1    germany
# 2  australia
# 3      korea
# 4    germany

# %%
df.fillna(df.median(),inplace=True)

# %% [markdown]
# ### Outlier Detection and Treatment
#
# Detection
# 1. Boxplot & Scatter part of visulization
# 2. Any value, which is beyond the range of -1.5 x IQR to 1.5 x IQR
# 3. using maethod where any values between N% to m% percentile
# 4. Also it can depend on business understadning or SME call
#
# Treatment
# 1. Deleting recrods
# 2. imputation of mean/mode/mdeium by considering those values as missing
# 3. Treat separately
# 4.

# %% [markdown]
# # Feature Engineering
#
# FEATURE NEED TO Transform
# 1. BY CHANGE THE SCALE
# 2. CONVERTE SKEW DISTRIBUTION TO SYSTMETIC DISTRIBUTION
# 3. some common method for trasofmration like squre root, log ..etc
#
# feture creation
#
# 1. Creating new derived featiures
# 2. dummy_varibales by transpose on categorical fetaures

# %%
import pandas as pd

df = pd.DataFrame({'country': ['russia', 'germany', 'australia','korea','germany']})

# %%
df
# Out:
#      country
# 0     russia
# 1    germany
# 2  australia
# 3      korea
# 4    germany

# %%
dfdummy=pd.get_dummies(df,prefix=['country'])

# %%
dfdummy
# Out:
#    country_australia  country_germany  country_korea  country_russia
# 0                  0                0              0               1
# 1                  0                1              0               0
# 2                  1                0              0               0
# 3                  0                0              1               0
# 4                  0                1              0               0

# %%
df1 =pd.concat([df, dfdummy], axis=1)

# %%
df1
# Out:
#      country  country_australia  country_germany  country_korea  \
# 0     russia                  0                0              0
# 1    germany                  0                1              0
# 2  australia                  1                0              0
# 3      korea                  0                0              1
# 4    germany                  0                1              0
#
#    country_russia
# 0               1
# 1               0
# 2               0
# 3               0
# 4               0

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
labelencoder.fit_transform(df1.iloc[:, 0])
# Out:
# array([3, 1, 0, 2, 1])

# %%
from sklearn.preprocessing import LabelEncoder

lb_make = LabelEncoder()
df1["make_num"] = lb_make.fit_transform(df1["country"])
df1[["make_num", "country"]].head(11)
# Out:
#    make_num    country
# 0         3     russia
# 1         1    germany
# 2         0  australia
# 3         2      korea
# 4         1    germany

# %%
#importing data 

pd.read_csv(filename) # From a CSV file
pd.read_table(filename) # From a delimited text file (like TSV)
pd.read_excel(filename) # From an Excel file
pd.read_sql(query, connection_object) # Reads from a SQL table/database
pd.read_json(json_string) # Reads from a JSON formatted string, URL or file.
pd.read_html(url) # Parses an html URL, string or file and extracts tables to a list of dataframes
pd.read_clipboard() # Takes the contents of your clipboard and passes it to read_table()
pd.DataFrame(dict) # From a dict, keys for columns names, values for data as lists

# %%
#Exploring Data
df.shape() # Prints number of rows and columns in dataframe
df.head(n) # Prints first n rows of the DataFrame
df.tail(n) # Prints last n rows of the DataFrame
df.info() # Index, Datatype and Memory information
df.describe() # Summary statistics for numerical columns
s.value_counts(dropna=False) # Views unique values and counts
df.apply(pd.Series.value_counts) # Unique values and counts for all columns
df.describe() # Summary statistics for numerical columns
df.mean() # Returns the mean of all columns
df.corr() # Returns the correlation between columns in a DataFrame
df.count() # Returns the number of non-null values in each DataFrame column
df.max() # Returns the highest value in each column
df.min() # Returns the lowest value in each column
df.median() # Returns the median of each column
df.std() # Returns the standard deviation of each column

# %%
#Selecting
df[col] # Returns column with label col as Series
df[[col1, col2]] # Returns Columns as a new DataFrame
s.iloc[0] # Selection by position (selects first element)
s.loc[0] # Selection by index (selects element at index 0)
df.iloc[0,:] # First row
df.iloc[0,0] # First element of first column

# %%
#Data Cleaning
df.columns = ['a','b','c'] # Renames columns
pd.isnull() # Checks for null Values, Returns Boolean Array
pd.notnull() # Opposite of s.isnull()
df.dropna() # Drops all rows that contain null values
df.dropna(axis=1) # Drops all columns that contain null values
df.dropna(axis=1,thresh=n) # Drops all rows have have less than n non null values
df.fillna(x) # Replaces all null values with x
s.fillna(s.mean()) # Replaces all null values with the mean (mean can be replaced with almost any function from the statistics section)
s.astype(float) # Converts the datatype of the series to float
s.replace(1,'one') # Replaces all values equal to 1 with 'one'
s.replace([1,3],['one','three']) # Replaces all 1 with 'one' and 3 with 'three'
df.rename(columns=lambda x: x + 1) # Mass renaming of columns
df.rename(columns={'old_name': 'new_ name'}) # Selective renaming
df.set_index('column_one') # Changes the index
df.rename(index=lambda x: x + 1) # Mass renaming of index

# %%
#Filter, Sort and Group By
df[df[col] > 0.5] # Rows where the col column is greater than 0.5
df[(df[col] > 0.5) & (df[col] < 0.7)] # Rows where 0.5 < col < 0.7
df.sort_values(col1) # Sorts values by col1 in ascending order
df.sort_values(col2,ascending=False) # Sorts values by col2 in descending order
df.sort_values([col1,col2], ascending=[True,False]) # Sorts values by col1 in ascending order then col2 in descending order
df.groupby(col) # Returns a groupby object for values from one column
df.groupby([col1,col2]) # Returns a groupby object values from multiple columns
df.groupby(col1)[col2].mean() # Returns the mean of the values in col2, grouped by the values in col1 (mean can be replaced with almost any function from the statistics section)
df.pivot_table(index=col1, values= col2,col3], aggfunc=mean) # Creates a pivot table that groups by col1 and calculates the mean of col2 and col3
df.groupby(col1).agg(np.mean) # Finds the average across all columns for every unique column 1 group
df.apply(np.mean) # Applies a function across each column
df.apply(np.max, axis=1) # Applies a function across each row

# %%
#Joining and Combining
df1.append(df2) # Adds the rows in df1 to the end of df2 (columns should be identical)
pd.concat([df1, df2],axis=1) # Adds the columns in df1 to the end of df2 (rows should be identical)
df1.join(df2,on=col1,how='inner') # SQL-style joins the columns in df1 with the columns on df2 where

# %%
#Writing Data
df.to_csv(filename) # Writes to a CSV file
df.to_excel(filename) # Writes to an Excel file
df.to_sql(table_name, connection_object) # Writes to a SQL table
df.to_json(filename) # Writes to a file in JSON format
df.to_html(filename) # Saves as an HTML table
df.to_clipboard() # Writes to the clipboard
